# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaythakur3369/The-Sparks-Foundation-Internship-Tasks/blob/main/Task_1_Prediction_using_Supervised_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name - Prediction using Supervised ML**
# ## **Developed By - Ajay Thakur (2016kuec2026@iiitkota.ac.in)**
# ## **Branch Name - Electronics and Communication Engineering**
# ## **Institute Name - Indian Institute of Information Technology Kota (An Institute of National Importance under an Act of Parliament)**
# ## **Submitted To - The Sparks Foundation**
# ## **Project Link (GitHub) - [Click here](https://github.com/ajaythakur3369/The-Sparks-Foundation-Internship-Tasks/blob/main/Task_1_Prediction_using_Supervised_ML.ipynb)**
# ## **Project Link (Drive) - [Click here](https://colab.research.google.com/drive/1x0AZ2Kl2RL665TwdVMv6Lbboe5Fabhdm)**

# %% [markdown]
# ![Task_1.png](data:image/png;base64,...)

# %% [markdown]
# # **Problem Statement -**

# %% [markdown]
# **Objective -** Predict the percentage of an student based on the no. of study hours.
#
# This is a simple linear regression task as it involves just 2 variables.
#
# You can use R, Python, SAS or any other tool.
#
# What will be predicted score if a student studies for 9.25 hrs/day?

# %% [markdown]
# # **General Guidelines -**

# %% [markdown]
# Task submission:
#
# 1.	Host the code on GitHub Repository (public). Record the code and output in a video. Post the video on YouTube
#
# 2. Share links of code (GitHub) and video (YouTube) as a post on your Linkedin profile, not TSF Network.
#
# 3. Submit the Linkedin link in Task Submission Form when shared.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ### **Import Libraries**

# %%
# Imported all the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# import library for training and testing data
from sklearn.model_selection import train_test_split

# import library for model training algorithm
from sklearn.linear_model import LinearRegression

# import library for model evaluation
from sklearn import metrics

# %% [markdown]
# ### **Reading the dataset**

# %%
# Access the Drive from Colab, for accessing required file
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
data = pd.read_csv('/content/drive/MyDrive/folders/Task_1_TSF_File.csv')
data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
# Check the shape of dataset
data.shape
# Out:
# (25, 2)

# %% [markdown]
# ### **Calculating all the constraint**

# %%
data.describe(include = [object, np.number])
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# ### **Displaying all the columns and their data types**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %% [markdown]
# ### **Checking is their exists any null values**

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# ### **As the datset has no null values, we can now visulize the data**

# %%
plt.figure(figsize = (7,5))
sns.scatterplot(y = data['Scores'], x = data['Hours'])
plt.title('Percentage Vs Study Hours')
plt.ylabel('Percentage')
plt.xlabel('Study Hours')
plt.show()

# %%
# Here, we can see that there is a correlation between percentage and study hours
plt.figure(figsize = (7,5))
sns.regplot(x = data['Hours'], y = data['Scores'])
plt.title('Regression plot for Scores')
plt.xlabel('Study Hours')
plt.ylabel('Percentage')
print(data.corr())
plt.show()
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %% [markdown]
# ### **Model Training**

# %%
# Separating Features and Labels
X = data.iloc[:, :-1].values  # Features
Y = data.iloc[:, 1].values  # labels

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .2, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (25, 1) (20, 1) (5, 1)

# %%
# Data fitting in the model
linear = LinearRegression()
linear.fit(X_train, Y_train)

print('Model is Training successful')
# Out:
# Model is Training successful

# %%
# Plotting regression line
line = linear.coef_*X + linear.intercept_

# %%
plt.figure(figsize = (7, 5))
plt.scatter(X, Y, marker = '.', color = 'b')
plt.plot(X, line, color = 'r')
plt.title("Study Hours v/s Percentage Scores")
plt.xlabel('Hours')
plt.ylabel("Scores")
plt.show()

# %%
# Accuracy on training data
training_data_accuracy = linear.score(X_train,Y_train)*100
print("Training Data Accuracy : ", training_data_accuracy)
# Out:
# Training Data Accuracy :  94.23348138802984

# %%
# Accuracy on test data
test_data_accuracy = linear.score(X_test, Y_test)*100
print("Test Data Accuracy : ", test_data_accuracy)
# Out:
# Test Data Accuracy :  97.35538080811827

# %% [markdown]
# ### **Predict Model**

# %%
# Prediction of the percentage
pred = linear.predict(X_test)
Prediction = pd.DataFrame({'Study Hours': [i[0] for i in X_test], 'Predicted Marks': [j for j in pred]})
Prediction
# Out:
#    Study Hours  Predicted Marks
# 0          1.1        12.442587
# 1          2.5        26.359448
# 2          1.9        20.395079
# 3          9.2        92.961570
# 4          6.9        70.098155

# %%
# Compare the predition marks and actual marks in the dataset
compare = pd.DataFrame({'Actual Marks': Y_test, 'Predict Marks': pred})
compare
# Out:
#    Actual Marks  Predict Marks
# 0            17      12.442587
# 1            21      26.359448
# 2            24      20.395079
# 3            88      92.961570
# 4            76      70.098155

# %%
# Predict marks and actual marks using data visulization
plt.figure(figsize = (7, 5))
plt.scatter(x = X_test, y = Y_test, color = 'Blue')
plt.plot(X_test, pred, color = 'Red')
plt.title('Actual vs Predicted')
plt.ylabel('Percentage of Marks')
plt.xlabel('Study Hours')
plt.show()

# %% [markdown]
# ### **What will be the predicted score if a student for 9.25 hrs per day?**

# %%
predict_the_hrs_per_day = linear.predict([[9.25]])
print("Predicted marks for a student studying for 9.25 hours/day : {}".format(predict_the_hrs_per_day))
# Out:
# Predicted marks for a student studying for 9.25 hours/day : [93.45860056]

# %% [markdown]
# ### **Model Evaluation**

# %%
# Calculate the accuracy of the model
mean_sqr_err = metrics.mean_squared_error(Y_test, pred)
print("Mean_squared_error: ", mean_sqr_err)
# Out:
# Mean_squared_error:  24.387620339856596

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, pred))
# Out:
# Mean Absolute Error: 4.877039354964476
