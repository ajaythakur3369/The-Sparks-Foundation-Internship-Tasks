# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaythakur3369/The-Sparks-Foundation-Internship-Tasks/blob/main/Task_7_Stock_Market_Prediction_using_Numerical_and_Textual_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name - Stock Market Prediction using Numerical and Textual Analysis**
# ## **Developed By - Ajay Thakur (2016kuec2026@iiitkota.ac.in)**
# ## **Branch Name - Electronics and Communication Engineering**
# ## **Institute Name - Indian Institute of Information Technology Kota (An Institute of National Importance under an Act of Parliament)**
# ## **Submitted To - The Sparks Foundation**
# ## **Project Link (GitHub) - [Click here](https://github.com/ajaythakur3369/The-Sparks-Foundation-Internship-Tasks/blob/main/Task_7_Stock_Market_Prediction_using_Numerical_and_Textual_Analysis.ipynb)**
# ## **Project Link (Drive) - [Click here](https://colab.research.google.com/drive/1MRQR1rWNJpU4eNgIUQL8GHQC_6HB9sgo)**

# %% [markdown]
# ![Task_7.png](data:image/png;base64,...)

# %% [markdown]
# # **Problem Statement -**

# %% [markdown]
# **Objective -** Create a hybrid model for stock price/performance prediction using numerical analysis of historical stock prices, and sentimental analysis of news headlines.
#
# Stock of analyze and predict – SENSEX (S&P BSE SENSEX)
#
# Use either R or Python, or both for separate analysis and then combine the findings to create a hybrid model
#
# You are free to select a different stock to analyze and news dataset as well while not changing the objective of the Task.

# %% [markdown]
# # **General Guidelines -**

# %% [markdown]
# Task submission:
#
# 1.	Host the code on GitHub Repository (public). Record the code and output in a video. Post the video on YouTube
#
# 2.	Share links of code (GitHub) and video (YouTube) as a post on Your Linkedin profile.
#
# 3.	Submit the Linkedin link in Task Submission Form when shared.
#
# 4.	Please read FAQs on how to submit the tasks.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ### **Import libraries**

# %%
# Imported all the required libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import yfinance as yf
import tensorflow as tf
from tensorflow import keras
# !pip install keras-tuner --upgrade

from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from textblob import TextBlob

import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.10/dist-packages (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.7.22)

# %%
# Collecting data from yahoo finance
# Train data
bse_data = yf.download('^BSESN', start = '2016-01-04', end = '2020-07-30')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# The shape of bse data
bse_data.shape
# Out:
# (1122, 6)

# %%
# Read data
bse_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2016-01-04  26116.519531  26116.519531  25596.570312  25623.349609
# 2016-01-05  25744.699219  25766.759766  25513.750000  25580.339844
# 2016-01-06  25628.230469  25632.570312  25357.699219  25406.330078
# 2016-01-07  25224.699219  25230.349609  24825.699219  24851.830078
# 2016-01-08  24969.019531  25083.550781  24887.220703  24934.330078
# ...                  ...           ...           ...           ...
# 2020-07-23  37814.921875  38225.031250  37738.589844  38140.468750
# 2020-07-24  37949.589844  38235.730469  37748.410156  38128.898438
# 2020-07-27  38275.339844  38275.339844  37769.441406  37934.730469
# 2020-07-28  38052.179688  38554.718750  37998.128906  38492.949219
# 2020-07-29  38427.148438  38617.031250  37884.410156  38071.128906
#
#                Adj Close  Volume
# Date
# 2016-01-04  25623.349609    9100
# 2016-01-05  25580.339844   10300
# 2016-01-06  25406.330078   13400
# 2016-01-07  24851.830078   11800
# 2016-01-08  24934.330078   15900
# ...                  ...     ...
# 2020-07-23  38140.468750   19600
# 2020-07-24  38128.898438   19900
# 2020-07-27  37934.730469   18600
# 2020-07-28  38492.949219   15500
# 2020-07-29  38071.128906   17600
#
# [1122 rows x 6 columns]

# %%
# Check total Columns
bse_data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# Rename the bse_data columns name
bse_data.rename(columns={'Open': 'open', 'High': 'high', 'Low': 'low', 'Close': 'close',
                         'Adj Close': 'adjclose', 'Volume': 'volume'}, inplace = True)

# %%
# Read dataset
bse_data
# Out:
#                     open          high           low         close  \
# Date
# 2016-01-04  26116.519531  26116.519531  25596.570312  25623.349609
# 2016-01-05  25744.699219  25766.759766  25513.750000  25580.339844
# 2016-01-06  25628.230469  25632.570312  25357.699219  25406.330078
# 2016-01-07  25224.699219  25230.349609  24825.699219  24851.830078
# 2016-01-08  24969.019531  25083.550781  24887.220703  24934.330078
# ...                  ...           ...           ...           ...
# 2020-07-23  37814.921875  38225.031250  37738.589844  38140.468750
# 2020-07-24  37949.589844  38235.730469  37748.410156  38128.898438
# 2020-07-27  38275.339844  38275.339844  37769.441406  37934.730469
# 2020-07-28  38052.179688  38554.718750  37998.128906  38492.949219
# 2020-07-29  38427.148438  38617.031250  37884.410156  38071.128906
#
#                 adjclose  volume
# Date
# 2016-01-04  25623.349609    9100
# 2016-01-05  25580.339844   10300
# 2016-01-06  25406.330078   13400
# 2016-01-07  24851.830078   11800
# 2016-01-08  24934.330078   15900
# ...                  ...     ...
# 2020-07-23  38140.468750   19600
# 2020-07-24  38128.898438   19900
# 2020-07-27  37934.730469   18600
# 2020-07-28  38492.949219   15500
# 2020-07-29  38071.128906   17600
#
# [1122 rows x 6 columns]

# %%
# Checking for missing values, size, datatypes etc
bse_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1122 entries, 2016-01-04 to 2020-07-29
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   open      1122 non-null   float64
#  1   high      1122 non-null   float64
#  2   low       1122 non-null   float64
#  3   close     1122 non-null   float64
#  4   adjclose  1122 non-null   float64
#  5   volume    1122 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 61.4 KB

# %%
bse_data = bse_data[['close']]
bse_data
# Out:
#                    close
# Date
# 2016-01-04  25623.349609
# 2016-01-05  25580.339844
# 2016-01-06  25406.330078
# 2016-01-07  24851.830078
# 2016-01-08  24934.330078
# ...                  ...
# 2020-07-23  38140.468750
# 2020-07-24  38128.898438
# 2020-07-27  37934.730469
# 2020-07-28  38492.949219
# 2020-07-29  38071.128906
#
# [1122 rows x 1 columns]

# %% [markdown]
# ### **Visulization**

# %%
# Plotting the closing price
index = bse_data.index
plt.figure(figsize = (10, 6))
sns.lineplot(x = index, y = bse_data['close'])
plt.show()
# Out:
# <Axes: xlabel='Date', ylabel='close'>

# %% [markdown]
# ### **Data Preprocessing**

# %%
# Scaling the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(bse_data)

# %%
scaled_data
# Out:
# array([[0.14060038],
#        [0.1383368 ],
#        [0.12917878],
#        ...,
#        [0.78854055],
#        [0.81791925],
#        [0.79571912]])

# %%
# Splitting the data
train_size = 0.80
len_train_data = round(len(bse_data) * train_size)
train_data = scaled_data[0 : len_train_data]
test_data = scaled_data[len_train_data :]

# %%
# The shape of training data and testing data
train_data.shape, test_data.shape
# Out:
# ((898, 1), (224, 1))

# %%
# Creating features for future prediction
# We will use past 90 days data to predict the present
def feature_extraction(data, start, end):
  X_train = []
  y_train=[]
  for i in range(start,end):
    X_train.append(data[i-50:i])
    y_train.append(data[i])
  return X_train, y_train

# %%
# Creating training data
X_train, y_train = feature_extraction(train_data, 50, len(train_data))

# Creating testing data
X_test,y_test = feature_extraction(test_data, 50, len(test_data))

# %%
# Converting the list to numpy array
# Training data
X_train = np.array(X_train)
y_train = np.array(y_train)

# Testing data
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
print(f'The shape of X_train : {X_train.shape}')
print(f'The shape of y_train : {y_train.shape}')
print(f'The shape of X_test : {X_test.shape}')
print(f'The shape of y_test : {y_test.shape}')
# Out:
# The shape of X_train : (848, 50, 1)
# The shape of y_train : (848, 1)
# The shape of X_test : (174, 50, 1)
# The shape of y_test : (174, 1)

# %%
# Creating X_train DataFrame
# In order to get the original value we should inverse transform the scaled data
# We inverse transform here because we will later use it for visualization
train_df = pd.DataFrame(scaler.inverse_transform(X_train.reshape(-1, 50)),
                        index = np.arange(0, len(X_train)))
train_df['target'] = scaler.inverse_transform(y_train)
train_df
# Out:
#                 0             1             2             3             4  \
# 0    25623.349609  25580.339844  25406.330078  24851.830078  24934.330078
# 1    25580.339844  25406.330078  24851.830078  24934.330078  24825.039062
# 2    25406.330078  24851.830078  24934.330078  24825.039062  24682.029297
# 3    24851.830078  24934.330078  24825.039062  24682.029297  24854.109375
# 4    24934.330078  24825.039062  24682.029297  24854.109375  24772.970703
# ..            ...           ...           ...           ...           ...
# 843  39784.519531  39950.460937  39756.808594  39741.359375  39452.070312
# 844  39950.460937  39756.808594  39741.359375  39452.070312  38960.789062
# 845  39756.808594  39741.359375  39452.070312  38960.789062  39046.339844
# 846  39741.359375  39452.070312  38960.789062  39046.339844  39112.738281
# 847  39452.070312  38960.789062  39046.339844  39112.738281  39601.628906
#
#                 5             6             7             8             9  \
# 0    24825.039062  24682.029297  24854.109375  24772.970703  24455.039062
# 1    24682.029297  24854.109375  24772.970703  24455.039062  24188.369141
# 2    24854.109375  24772.970703  24455.039062  24188.369141  24479.839844
# 3    24772.970703  24455.039062  24188.369141  24479.839844  24062.039063
# 4    24455.039062  24188.369141  24479.839844  24062.039063  23962.210937
# ..            ...           ...           ...           ...           ...
# 843  38960.789062  39046.339844  39112.738281  39601.628906  39194.488281
# 844  39046.339844  39112.738281  39601.628906  39194.488281  39122.960938
# 845  39112.738281  39601.628906  39194.488281  39122.960938  39434.941406
# 846  39601.628906  39194.488281  39122.960938  39434.941406  39592.078125
# 847  39194.488281  39122.960938  39434.941406  39592.078125  39586.410156
#
#      ...            41            42            43            44  \
# 0    ...  24242.980469  24606.990234  24646.480469  24659.230469
# 1    ...  24606.990234  24646.480469  24659.230469  24793.960938
# 2    ...  24646.480469  24659.230469  24793.960938  24623.339844
# 3    ...  24659.230469  24793.960938  24623.339844  24717.990234
# 4    ...  24793.960938  24623.339844  24717.990234  24804.279297
# ..   ...           ...           ...           ...           ...
# 843  ...  36976.851562  36690.500000  37327.359375  37581.910156
# 844  ...  36690.500000  37327.359375  37581.910156  36958.160156
# 845  ...  37327.359375  37581.910156  36958.160156  37311.531250
# 846  ...  37581.910156  36958.160156  37311.531250  37350.328125
# 847  ...  36958.160156  37311.531250  37350.328125  37402.488281
#
#                45            46            47            48            49  \
# 0    24793.960938  24623.339844  24717.990234  24804.279297  24551.169922
# 1    24623.339844  24717.990234  24804.279297  24551.169922  24682.480469
# 2    24717.990234  24804.279297  24551.169922  24682.480469  24677.369141
# 3    24804.279297  24551.169922  24682.480469  24677.369141  24952.740234
# 4    24551.169922  24682.480469  24677.369141  24952.740234  25285.369141
# ..            ...           ...           ...           ...           ...
# 843  36958.160156  37311.531250  37350.328125  37402.488281  37328.011719
# 844  37311.531250  37350.328125  37402.488281  37328.011719  37060.371094
# 845  37350.328125  37402.488281  37328.011719  37060.371094  36472.929688
# 846  37402.488281  37328.011719  37060.371094  36472.929688  36701.160156
# 847  37328.011719  37060.371094  36472.929688  36701.160156  37494.121094
#
#            target
# 0    24682.480469
# 1    24677.369141
# 2    24952.740234
# 3    25285.369141
# 4    25330.490234
# ..            ...
# 843  37060.371094
# 844  36472.929688
# 845  36701.160156
# 846  37494.121094
# 847  37641.269531
#
# [848 rows x 51 columns]

# %%
# Creating X test DataFrame
test_df = pd.DataFrame(scaler.inverse_transform(X_test.reshape(-1, 50)),
                       index = np.arange(len(X_train), len(X_train) + len(X_test)))
test_df['target'] = scaler.inverse_transform(y_test)
test_df
# Out:
#                  0             1             2             3             4  \
# 848   37451.839844  37068.929688  37332.789062  36562.910156  36724.738281
# 849   37068.929688  37332.789062  36562.910156  36724.738281  36644.421875
# 850   37332.789062  36562.910156  36724.738281  36644.421875  36981.769531
# 851   36562.910156  36724.738281  36644.421875  36981.769531  37145.449219
# 852   36724.738281  36644.421875  36981.769531  37145.449219  37270.820312
# ...            ...           ...           ...           ...           ...
# 1017  32008.609375  31122.890625  31097.730469  30028.980469  30196.169922
# 1018  31122.890625  31097.730469  30028.980469  30196.169922  30818.609375
# 1019  31097.730469  30028.980469  30196.169922  30818.609375  30932.900391
# 1020  30028.980469  30196.169922  30818.609375  30932.900391  30672.589844
# 1021  30196.169922  30818.609375  30932.900391  30672.589844  30609.300781
#
#                  5             6             7             8             9  \
# 848   36644.421875  36981.769531  37145.449219  37270.820312  37104.281250
# 849   36981.769531  37145.449219  37270.820312  37104.281250  37384.988281
# 850   37145.449219  37270.820312  37104.281250  37384.988281  37123.308594
# 851   37270.820312  37104.281250  37384.988281  37123.308594  36481.089844
# 852   37104.281250  37384.988281  37123.308594  36481.089844  36563.878906
# ...            ...           ...           ...           ...           ...
# 1017  30818.609375  30932.900391  30672.589844  30609.300781  31605.220703
# 1018  30932.900391  30672.589844  30609.300781  31605.220703  32200.589844
# 1019  30672.589844  30609.300781  31605.220703  32200.589844  32424.099609
# 1020  30609.300781  31605.220703  32200.589844  32424.099609  33303.519531
# 1021  31605.220703  32200.589844  32424.099609  33303.519531  33825.531250
#
#       ...            41            42            43            44  \
# 848   ...  40165.031250  40301.960938  40248.230469  40469.781250
# 849   ...  40301.960938  40248.230469  40469.781250  40653.738281
# 850   ...  40248.230469  40469.781250  40653.738281  40323.609375
# 851   ...  40469.781250  40653.738281  40323.609375  40345.078125
# 852   ...  40653.738281  40323.609375  40345.078125  40116.058594
# ...   ...           ...           ...           ...           ...
# 1017  ...  36594.328125  36693.691406  36033.058594  36051.808594
# 1018  ...  36693.691406  36033.058594  36051.808594  36471.679688
# 1019  ...  36033.058594  36051.808594  36471.679688  37020.140625
# 1020  ...  36051.808594  36471.679688  37020.140625  37418.988281
# 1021  ...  36471.679688  37020.140625  37418.988281  37930.328125
#
#                 45            46            47            48            49  \
# 848   40653.738281  40323.609375  40345.078125  40116.058594  40286.480469
# 849   40323.609375  40345.078125  40116.058594  40286.480469  40356.691406
# 850   40345.078125  40116.058594  40286.480469  40356.691406  40284.191406
# 851   40116.058594  40286.480469  40356.691406  40284.191406  40469.699219
# 852   40286.480469  40356.691406  40284.191406  40469.699219  40651.640625
# ...            ...           ...           ...           ...           ...
# 1017  36471.679688  37020.140625  37418.988281  37930.328125  37871.519531
# 1018  37020.140625  37418.988281  37930.328125  37871.519531  38140.468750
# 1019  37418.988281  37930.328125  37871.519531  38140.468750  38128.898438
# 1020  37930.328125  37871.519531  38140.468750  38128.898438  37934.730469
# 1021  37871.519531  38140.468750  38128.898438  37934.730469  38492.949219
#
#             target
# 848   40356.691406
# 849   40284.191406
# 850   40469.699219
# 851   40651.640625
# 852   40575.171875
# ...            ...
# 1017  38140.468750
# 1018  38128.898438
# 1019  37934.730469
# 1020  38492.949219
# 1021  38071.128906
#
# [174 rows x 51 columns]

# %% [markdown]
# ### **Building model**

# %%
model = keras.Sequential()
model.add(keras.layers.LSTM(units = 384, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(keras.layers.LSTM(units = 384, return_sequences = True))
model.add(keras.layers.LSTM(units = 384, return_sequences = True))
model.add(keras.layers.LSTM(units = 384, return_sequences = False))
model.add(keras.layers.Dense(units = 1, activation = "sigmoid"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 50, 384)           592896
#
#  lstm_5 (LSTM)               (None, 50, 384)           1181184
#
#  lstm_6 (LSTM)               (None, 50, 384)           1181184
#
#  lstm_7 (LSTM)               (None, 384)               1181184
#
#  dense_1 (Dense)             (None, 1)                 385
#
# =================================================================
# Total params: 4136833 (15.78 MB)
# Trainable params: 4136833 (15.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mse')
callback_chk = keras.callbacks.ModelCheckpoint(filepath = 'best_model.h5', save_best_only = True)
model_history = model.fit(X_train, y_train, epochs = 30, validation_data = (X_test, y_test), callbacks = [callback_chk])
# Out:
# Epoch 1/30
# 27/27 [==============================] - 89s 3s/step - loss: 0.0281 - val_loss: 0.0384
# Epoch 2/30
# 27/27 [==============================] - 49s 2s/step - loss: 0.0035 - val_loss: 0.0251
# Epoch 3/30
# 27/27 [==============================] - 54s 2s/step - loss: 0.0020 - val_loss: 0.0201
# Epoch 4/30
# 27/27 [==============================] - 51s 2s/step - loss: 0.0020 - val_loss: 0.0186
# Epoch 5/30
# 27/27 [==============================] - 53s 2s/step - loss: 0.0019 - val_loss: 0.0157
# Epoch 6/30
# 27/27 [==============================] - 50s 2s/step - loss: 0.0017 - val_loss: 0.0138
# Epoch 7/30
# 27/27 [==============================] - 53s 2s/step - loss: 0.0013 - val_loss: 0.0120
# Epoch 8/30
# 27/27 [==============================] - 51s 2s/step - loss: 0.0011 - val_loss: 0.0096
# Epoch 9/30
# 27/27 [==============================] - 53s 2s/step - loss: 0.0011 - val_loss: 0.0090
# Epoch 10/30
# 27/27 [==============================] - 49s 2s/step - loss: 0.0011 - val_loss: 0.0089
# Epoch 11/30
# 27/27 [==============================] - 49s 2s/step - loss: 9.7604e-04 - val_loss: 0.0079
# Epoch 12/30
# 27/27 [==============================] - 50s 2s/step - loss: 0.0011 - val_loss: 0.0070
# Epoch 13/30
# 27/27 [==============================] - 48s 2s/step - loss: 8.7265e-04 - val_loss: 0.0066
# Epoch 14/30
# 27/27 [==============================] - 48s 2s/step - loss: 0.0013 - val_loss: 0.0069
# Epoch 15/30
# 27/27 [==============================] - 48s 2s/step - loss: 9.4884e-04 - val_loss: 0.0073
# Epoch 16/30
# 27/27 [==============================] - 50s 2s/step - loss: 8.2921e-04 - val_loss: 0.0054
# Epoch 17/30
# 27/27 [==============================] - 49s 2s/step - loss: 7.7219e-04 - val_loss: 0.0054
# Epoch 18/30
# 27/27 [==============================] - 52s 2s/step - loss: 8.7368e-04 - val_loss: 0.0079
# Epoch 19/30
# 27/27 [==============================] - 49s 2s/step - loss: 8.6758e-04 - val_loss: 0.0055
# Epoch 20/30
# 27/27 [==============================] - 50s 2s/step - loss: 9.6395e-04 - val_loss: 0.0061
# Epoch 21/30
# 27/27 [==============================] - 51s 2s/step - loss: 7.5856e-04 - val_loss: 0.0046
# Epoch 22/30
# 27/27 [==============================] - 51s 2s/step - loss: 6.8569e-04 - val_loss: 0.0049
# Epoch 23/30
# 27/27 [==============================] - 52s 2s/step - loss: 6.9397e-04 - val_loss: 0.0043
# Epoch 24/30
# 27/27 [==============================] - 50s 2s/step - loss: 6.4824e-04 - val_loss: 0.0038
# Epoch 25/30
# 27/27 [==============================] - 52s 2s/step - loss: 6.0102e-04 - val_loss: 0.0035
# Epoch 26/30
# 27/27 [==============================] - 50s 2s/step - loss: 5.4190e-04 - val_loss: 0.0034
# Epoch 27/30
# 27/27 [==============================] - 53s 2s/step - loss: 5.3403e-04 - val_loss: 0.0032
# Epoch 28/30
# 27/27 [==============================] - 48s 2s/step - loss: 5.2304e-04 - val_loss: 0.0039
# Epoch 29/30
# 27/27 [==============================] - 48s 2s/step - loss: 6.0608e-04 - val_loss: 0.0034
# Epoch 30/30
# 27/27 [==============================] - 51s 2s/step - loss: 5.8026e-04 - val_loss: 0.0034

# %%
model = keras.models.load_model('best_model.h5')

# %%
# Plotting the losses
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
index = np.arange(30)
sns.lineplot(x = index, y = loss)
sns.lineplot(x = index, y = val_loss)
plt.ylabel('loss')
plt.xlabel('iterations')
plt.legend(['training loss','validation loss'])
plt.show()

# %% [markdown]
# ### **Making predictions**

# %%
# Lets try to predict with some data
preds = model.predict(X_test)
# Out:
# 6/6 [==============================] - 4s 365ms/step

# %%
# Performing inverse transformation on predictions and actual value
preds_inv = scaler.inverse_transform(preds)
y_test_inv = scaler.inverse_transform(y_test)

# %%
# Evaluating the performance of the model
# MAE
print('MAE : ', mean_absolute_error(y_test_inv, preds_inv), end = '\n')

# MSE
print('MSE : ', mean_squared_error(y_test_inv, preds_inv), end = '\n')

# RMSE
print('RMSE : ', np.sqrt(mean_squared_error(y_test_inv, preds_inv)))
# Out:
# MAE :  872.7978627873563
# MSE :  1173126.2158122007
# RMSE :  1083.10951238192

# %%
# R squared
r2_score(y_test_inv, preds_inv)
# Out:
# 0.9416120796597003

# %% [markdown]
# ### **Graphical analysis**

# %%
# Plotting the training data,testing data and predicted data
plt.figure(figsize = (7,5))
train_df['target'].plot()
test_df['target'].plot()

test_df['predictions'] = preds_inv
test_df['predictions'].plot()

plt.xlabel('indices')
plt.ylabel('Closing price')
plt.legend(['training','actual','predictions'])
plt.show()

# %%
# Zooming the predictions portion
plt.plot(preds_inv)
plt.plot(y_test_inv)

plt.legend(['predictions','actual'])
plt.xlabel('indices')
plt.ylabel('Closing price')
plt.show()

# %% [markdown]
# ### **Textual analysis of news report**

# %%
# Access the Drive from Colab, for accessing required file
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
data_news = pd.read_csv('/content/drive/MyDrive/folders/Task_7_TSF_File.csv')

# %%
data_news.head()
# Out:
#    publish_date headline_category  \
# 0      20010102           unknown
# 1      20010102           unknown
# 2      20010102           unknown
# 3      20010102           unknown
# 4      20010102           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %%
# Converting the publish date data type to date time
data_news['Date'] = pd.to_datetime(data_news['publish_date'], format = '%Y%m%d')
data_news.drop(columns = 'publish_date', inplace = True)

# %%
data_news
# Out:
#                      headline_category  \
# 0                              unknown
# 1                              unknown
# 2                              unknown
# 3                              unknown
# 4                              unknown
# ...                                ...
# 3650965                  city.srinagar
# 3650966  entertainment.hindi.bollywood
# 3650967                    city.trichy
# 3650968                     city.erode
# 3650969                     city.salem
#
#                                              headline_text       Date
# 0        Status quo will not be disturbed at Ayodhya; s... 2001-01-02
# 1                      Fissures in Hurriyat over Pak visit 2001-01-02
# 2                    America's unwanted heading for India? 2001-01-02
# 3                       For bigwigs; it is destination Goa 2001-01-02
# 4                     Extra buses to clear tourist traffic 2001-01-02
# ...                                                    ...        ...
# 3650965  J&K sacks 2 cops; 3 other employees over terro... 2022-03-31
# 3650966  Ranbir Kapoor says 'Rishi Kapoor enjoyed his a... 2022-03-31
# 3650967  As Covid-19 cases drop to nil in southern dist... 2022-03-31
# 3650968  Tamil Nadu sees marginal rise of Covid cases w... 2022-03-31
# 3650969  Tamil Nadu sees marginal rise of Covid cases w... 2022-03-31
#
# [3650970 rows x 3 columns]

# %%
# How Textblob works
test = 'I am a not very good girl'
TextBlob(test).sentiment
# Out:
# Sentiment(polarity=-0.26923076923076916, subjectivity=0.46153846153846156)

# %%
# Fucntions to obtain polarity and subjectivity from the text
def polarity(text):
  pol_val = TextBlob(text).sentiment.polarity
  return pol_val
def subjectivity(text):
  sub_val = TextBlob(text).sentiment.subjectivity
  return sub_val

# %%
data_news['polarity'] = data_news['headline_text'].apply(polarity)
data_news['subjectivity'] = data_news['headline_text'].apply(subjectivity)

# %%
# Function for Sentiment analysis
def sentiment_analysis(polarity_val):
  if polarity_val > 0:
    senti_val = 'Positive'
  elif polarity_val == 0:
    senti_val = "Neutral"
  else:
    senti_val = 'Negative'
  return senti_val

# %%
data_news['Sentiment'] = data_news['polarity'].apply(sentiment_analysis)

# %%
data_news
# Out:
#                      headline_category  \
# 0                              unknown
# 1                              unknown
# 2                              unknown
# 3                              unknown
# 4                              unknown
# ...                                ...
# 3650965                  city.srinagar
# 3650966  entertainment.hindi.bollywood
# 3650967                    city.trichy
# 3650968                     city.erode
# 3650969                     city.salem
#
#                                              headline_text       Date  \
# 0        Status quo will not be disturbed at Ayodhya; s... 2001-01-02
# 1                      Fissures in Hurriyat over Pak visit 2001-01-02
# 2                    America's unwanted heading for India? 2001-01-02
# 3                       For bigwigs; it is destination Goa 2001-01-02
# 4                     Extra buses to clear tourist traffic 2001-01-02
# ...                                                    ...        ...
# 3650965  J&K sacks 2 cops; 3 other employees over terro... 2022-03-31
# 3650966  Ranbir Kapoor says 'Rishi Kapoor enjoyed his a... 2022-03-31
# 3650967  As Covid-19 cases drop to nil in southern dist... 2022-03-31
# 3650968  Tamil Nadu sees marginal rise of Covid cases w... 2022-03-31
# 3650969  Tamil Nadu sees marginal rise of Covid cases w... 2022-03-31
#
#          polarity  subjectivity Sentiment
# 0        0.000000      0.000000   Neutral
# 1        0.000000      0.000000   Neutral
# 2        0.000000      0.000000   Neutral
# 3        0.000000      0.000000   Neutral
# 4        0.050000      0.241667  Positive
# ...           ...           ...       ...
# 3650965 -0.125000      0.375000  Negative
# 3650966  0.100000      0.550000  Positive
# 3650967  0.000000      0.000000   Neutral
# 3650968  0.136364      0.454545  Positive
# 3650969  0.136364      0.454545  Positive
#
# [3650970 rows x 6 columns]

# %%
# Dropping duplicate rows
data_news.drop_duplicates(inplace = True)

# %%
data_news.reset_index(inplace = True)

# %%
data_news.drop(columns = 'index', inplace = True)

# %%
# Printing some Positive,Negative and Neutral text
# Positive
count = 0
for i in range(0, 50):
  if data_news['Sentiment'][i] == 'Positive':
    print(str(count) + "  " + data_news['headline_text'][i])
    count += 1
# Out:
# 0  Extra buses to clear tourist traffic
# 1  Will Qureshi's return really help the govt?
# 2  Come to Nandi Hills...and you can fly
# 3  HAL approached for super jumbo project
# 4  The best music of the year
# 5  Planning Dept seeks Rs 350 crore more
# 6  More engg colleges if needed in state: Govt
# 7  Akki-Alur and Ranebennur peaceful

# %%
# Negtaive
count = 0
for i in range(0,50):
  if data_news['Sentiment'][i] == 'Negative':
    print(str(count) + "  " + data_news['headline_text'][i])
    count += 1
# Out:
# 0  Destroying myths and doubts on sexuality

# %%
# Neutral
count = 0
for i in range(0,50):
  if data_news['Sentiment'][i] == 'Neutral':
    print(str(count) +"  " + data_news['headline_text'][i])
    count += 1
# Out:
# 0  Status quo will not be disturbed at Ayodhya; says Vajpayee
# 1  Fissures in Hurriyat over Pak visit
# 2  America's unwanted heading for India?
# 3  For bigwigs; it is destination Goa
# 4  Dilute the power of transfers; says Riberio
# 5  Focus shifts to teaching of Hindi
# 6  IT will become compulsory in schools
# 7  Move to stop freedom fighters' pension flayed
# 8  Gilani claims he applied for passport 2 years ago
# 9  Parivar dismisses PM's warning
# 10  India; Pak exchange lists of N-plants
# 11  PM's tacit message: Put Ram tample on hold
# 12  Text of the Prime Minister's article
# 13  NCW to focus on violence against women
# 14  BBC's reality TV will focus on AIIMS
# 15  Jaitley firm on legal reforms
# 16  Hoshangabad farmers have enough water
# 17  BJP jumps into rail track conversion issue
# 18  State may take AP to court over Krishna
# 19  This official has sued the briber
# 20  Park turns temple compound as residents watch
# 21  Moves afoot to evict squatters in Urban dist
# 22  Mafia calls the shots in Gandhinagar too
# 23  Nagathihalli returns with Preethiya Hudugi
# 24  Fashion in the future
# 25  Promises to keep
# 26  Home is where the holistic science is
# 27  A noisy effort to spruce up Commercial Street
# 28  Redemption night; amid some rock
# 29  Consul is back from month-long leave
# 30  Bomb hoax triggers panic in Canara Bank
# 31  Petition over ministers' assets dismissed
# 32  He beat polio; but a truck driver's is no life
# 33  Auto driver's murder: 4 held
# 34  Meet held on cashew crop forecasting
# 35  Awareness rally on AIDS today
# 36  Record power generation at RTPS
# 37  Snags delay digital maps of city
# 38  Making education a people's movement
# 39  Murder spoils 2001 party in Dharwad
# 40  Now a website on a seer

# %%
# Visualizing the number of Poitive,Negative and Neutral classes
plt.figure(figsize = (8, 5))
data_news['Sentiment'].value_counts().plot(kind = 'bar')
plt.xlabel('Sentiment')
plt.ylabel('Total values')
plt.show()
# Out:
# Text(0, 0.5, 'Total values')

# %%
# Merging the stocks dataframe and the news dataframe on date column
data_final = pd.merge(data_news, bse_data, on = "Date", how = 'right')

# %%
data_final
# Out:
#                               headline_category  \
# 0             life-style.health-fitness.fitness
# 1       life-style.health-fitness.home-remedies
# 2                             life-style.beauty
# 3            life-style.relationships.parenting
# 4            life-style.relationships.man-woman
# ...                                         ...
# 702348                               city.delhi
# 702349                               city.delhi
# 702350                               city.delhi
# 702351                              city.nagpur
# 702352                              city.nagpur
#
#                                             headline_text       Date  \
# 0                   Surprising facts about exercise sweat 2016-01-04
# 1               Bizarre home remedies for the common cold 2016-01-04
# 2                       How to wear makeup when you're 30 2016-01-04
# 3                                      What's your style? 2016-01-04
# 4                Bizarre reasons Indians cite for divorce 2016-01-04
# ...                                                   ...        ...
# 702348  AAP-BJP row over corpn taxes spills on to streets 2020-07-29
# 702349           Nearly 3L job seekers register on portal 2020-07-29
# 702350            Covid Duty: Hotels Allowed To Check Out 2020-07-29
# 702351  Cadasta Foundation; Waatavaran to secure fores... 2020-07-29
# 702352  Jalaj Sharma joins as additional municipal com... 2020-07-29
#
#         polarity  subjectivity Sentiment         close
# 0       0.700000           0.5  Positive  25623.349609
# 1      -0.166667           0.7  Negative  25623.349609
# 2       0.000000           0.0   Neutral  25623.349609
# 3       0.000000           0.0   Neutral  25623.349609
# 4       0.400000           0.6  Positive  25623.349609
# ...          ...           ...       ...           ...
# 702348  0.000000           0.0   Neutral  38071.128906
# 702349  0.100000           0.4  Positive  38071.128906
# 702350  0.000000           0.0   Neutral  38071.128906
# 702351  0.400000           0.6  Positive  38071.128906
# 702352  0.000000           0.0   Neutral  38071.128906
#
# [702353 rows x 7 columns]

# %%
# Grouping
data_final.groupby('Sentiment')['close'].mean()
# Out:
# Sentiment
# Negative    32869.169796
# Neutral     32593.562183
# Positive    32649.965569
# Name: close, dtype: float64

# %%
# Creting dummy variables for sentiment column
data_final = pd.get_dummies(data = data_final, columns = ['Sentiment'])

# %%
data_final.head()
# Out:
#                          headline_category  \
# 0        life-style.health-fitness.fitness
# 1  life-style.health-fitness.home-remedies
# 2                        life-style.beauty
# 3       life-style.relationships.parenting
# 4       life-style.relationships.man-woman
#
#                                headline_text       Date  polarity  \
# 0      Surprising facts about exercise sweat 2016-01-04  0.700000
# 1  Bizarre home remedies for the common cold 2016-01-04 -0.166667
# 2          How to wear makeup when you're 30 2016-01-04  0.000000
# 3                         What's your style? 2016-01-04  0.000000
# 4   Bizarre reasons Indians cite for divorce 2016-01-04  0.400000
#
#    subjectivity         close  Sentiment_Negative  Sentiment_Neutral  \
# 0           0.5  25623.349609                   0                  0
# 1           0.7  25623.349609                   1                  0
# 2           0.0  25623.349609                   0                  1
# 3           0.0  25623.349609                   0                  1
# 4           0.6  25623.349609                   0                  0
#
#    Sentiment_Positive
# 0                   1
# 1                   0
# 2                   0
# 3                   0
# 4                   1

# %%
# Plotting Correlation  Matrix
corr_data = data_final[['Sentiment_Positive','Sentiment_Negative','Sentiment_Neutral','close']].corr()
sns.heatmap(corr_data, annot = True, cmap = 'RdPu')
plt.show()
# Out:
# <Axes: >

# %% [markdown]
# ### **Conclusion**
#
# **We can finally conclude that the Stock prices are somewhat negatively correlated with the sentiment of the news headlines**
